# %%
import numpy as np
import matplotlib.pyplot as plt
from parse_file import parse_Gaussian_file
from plot_functions import plot_spectra_nm

# %%
#function to convert machine absorption to ext.coeff, I assumed cavity length=1
def abs(abs):
    return [(i/0.000002) for i in abs]

# %%
#Spectra Rhodamine 6G 
nm_abs_rho6G_NAOH, abs_rho6G_NAOH = np.loadtxt('experimental/200220_abs_0,1MNaOH_2,0uM_Rho6G.TXT', unpack=True)
nm_abs_rho6G_ETOH, abs_rho6G_ETOH=np.loadtxt('experimental/200220_abs_EtOH_2,0uM_Rho6G.TXT', unpack=True)
nm_abs_rho6G_MECN, abs_rho6G_MECN=np.loadtxt('experimental/200220_abs_MeCN_2,0uM_Rho6G.TXT', unpack=True)
nm_abs_rho6G_EtOH_high, abs_rho6G_EtOH_high = np.loadtxt('experimental/200220_abs_NaOH-EtOH_2,0uM_Rho6G.TXT', unpack=True)
nm_abs_rho6G_MECN_high, abs_rho6G_MECN_high = np.loadtxt('experimental/200220_abs_NaOH-MeCN_2,0uM_Rho6G.TXT', unpack=True)

nm_em_rho6G_NAOH, em_rho6G_NAOH= np.loadtxt('experimental/200220_em_0,1MNaOH_2,0uM_Rho6G.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_rho6G_ETOH, em_rho6G_ETOH= np.loadtxt('experimental/200220_em_EtOH_2,0uM_Rho6G.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_rho6G_MeCN, em_rho6G_MeCN = np.loadtxt('experimental/200220_em_MeCN_2,0uM_Rho6G.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_rho6G_ETOH_high, em_rho6G_ETOH_high = np.loadtxt('experimental/200220_em_NaOH-EtOH_2,0uM_Rho6G.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_rho6G_MeCN_high, em_rho6G_MeCN_high = np.loadtxt('experimental/200220_em_NaOH-MeCN_2,0uM_Rho6G.ifx', usecols=(0,1), unpack=True, skiprows=28)

energR6G, oscR6G = parse_Gaussian_file('theoretical/R6GES.log')
energR6G_wat, oscR6G_wat = parse_Gaussian_file('theoretical/R6G_CPCM_waterES.log')
energR6G_eth, oscR6G_eth = parse_Gaussian_file('theoretical/R6G_CPCM_ethanolES.log')
energR6G_acet, oscR6G_acet = parse_Gaussian_file('theoretical/R6G_CPCM_acetoES.log')

plt.plot(nm_abs_rho6G_NAOH, abs(abs_rho6G_NAOH), label='NaOH')
plt.plot(nm_abs_rho6G_ETOH, abs(abs_rho6G_ETOH), label='EtOH')
plt.plot(nm_abs_rho6G_MECN, abs(abs_rho6G_MECN), label='MECN')
plt.plot(nm_abs_rho6G_EtOH_high, abs(abs_rho6G_EtOH_high), label='EtOH, high pH')
plt.plot(nm_abs_rho6G_MECN_high, abs(abs_rho6G_MECN_high), label='MECN, high pH')
plt.legend()
plt.ylabel('$L\ mol^{-1}cm^{-1}$')
plt.title('Absorption Rhodamine 6G')
plt.xlim(300, 650)
plt.ylim(0,150000)
plt.show()

plt.plot(nm_em_rho6G_NAOH, em_rho6G_NAOH, label = 'NAOH')
plt.plot(nm_em_rho6G_ETOH, em_rho6G_ETOH, label = 'EtOH')
plt.plot(nm_em_rho6G_MeCN, em_rho6G_MeCN, label = 'MECN') 
plt.plot(nm_em_rho6G_ETOH_high, em_rho6G_ETOH_high, label = 'ETOH, high pH')
plt.plot(nm_em_rho6G_MeCN_high, em_rho6G_MeCN_high, label = 'MECN, high pH')
plt.legend()
plt.ylabel('$L\ mol^{-1}cm^{-1}$')
plt.title('Emission Rhodamine 6G')

# plot_spectra_nm(energR6G, oscR6G, legend='Gas-phase')
# plot_spectra_nm(energR6G, oscR6G, legend='Gas-phase')
# plot_spectra_nm(energR6G_wat, oscR6G_wat, legend='PCM-water')
# plot_spectra_nm(energR6G_eth, oscR6G_eth, legend='PCM-ethanol')
# plot_spectra_nm(energR6G_acet, oscR6G_acet, legend='PCM-acetonitrile')
# Out:
# Text(0.5, 1.0, 'Emission Rhodamine 6G')

# %%
#Spectra Rhodamine B
nm_abs_rhoB_NAOH, abs_rhoB_NAOH = np.loadtxt('experimental/200220_abs_0,1MNaOH_2,0uM_RhoB.TXT', unpack=True)
nm_abs_rhoB_ETOH, abs_rhoB_ETOH=np.loadtxt('experimental/200220_abs_EtOH_2,0uM_RhoB.TXT', unpack=True)
nm_abs_rhoB_MECN, abs_rhoB_MECN=np.loadtxt('experimental/200220_abs_MeCN_2,0uM_RhoB.TXT', unpack=True)
nm_abs_rhoB_EtOH_high, abs_rhoB_EtOH_high = np.loadtxt('experimental/200220_abs_NaOH-EtOH_2,0uM_RhoB.TXT', unpack=True)
nm_abs_rhoB_MECN_high, abs_rhoB_MECN_high = np.loadtxt('experimental/200220_abs_NaOH-MeCN_2,0uM_RhoB.TXT', unpack=True)

nm_em_rhoB_NAOH, em_rhoB_NAOH = np.loadtxt('experimental/200220_em_0,1MNaOH_2,0uM_RhoB.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_rhoB_ETOH, em_rhoB_ETOH = np.loadtxt('experimental/200220_em_EtOH_2,0uM_RhoB.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_rhoB_MECN, em_rhoB_MECN = np.loadtxt('experimental/200220_em_MeCN_2,0uM_RhoB.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_rhoB_ETOH_high, em_rhoB_ETOH_high = np.loadtxt('experimental/200220_em_NaOH-EtOH_2,0uM_RhoB.ifx', usecols=(0,1), unpack=True, skiprows=28) 
nm_em_rhoB_MECN_high, em_rhoB_MECN_high = np.loadtxt('experimental/200220_em_NaOH-MeCN_2,0uM_RhoB.ifx', usecols=(0,1), unpack=True, skiprows=28)

energRhB, oscRhB = parse_Gaussian_file('theoretical/RhBES.log')
energRhB_wat, oscRhB_wat = parse_Gaussian_file('theoretical/RhB_CPCM_waterES.log')
energRhB_eth, oscRhB_eth = parse_Gaussian_file('theoretical/RhB_CPCM_ethanolES.log')
energRhB_acet, oscRhB_acet = parse_Gaussian_file('theoretical/RhB_CPCM_acetoES.log')

plt.plot(nm_abs_rhoB_NAOH, abs(abs_rhoB_NAOH), label='NaOH')
plt.plot(nm_abs_rhoB_ETOH, abs(abs_rhoB_ETOH), label='EtOH')
plt.plot(nm_abs_rhoB_MECN, abs(abs_rhoB_MECN), label='MECN')
plt.plot(nm_abs_rhoB_EtOH_high, abs(abs_rhoB_EtOH_high), label='EtOH, high pH')
plt.plot(nm_abs_rhoB_MECN_high, abs(abs_rhoB_MECN_high), label='MECN, high pH')
plt.legend()
plt.ylabel('$L\ mol^{-1}cm^{-1}$')
plt.title('Absorption Rhodamine B')
plt.xlim(300, 650)
plt.ylim(0,150000)
plt.show()
plt.plot(nm_em_rhoB_NAOH, em_rhoB_NAOH, label = 'NAOH')
plt.plot(nm_em_rhoB_ETOH, em_rhoB_ETOH, label = 'EtOH')
plt.plot(nm_em_rhoB_MECN, em_rhoB_MECN, label = 'MECN') 
plt.plot(nm_em_rhoB_ETOH_high, em_rhoB_ETOH_high, label = 'ETOH, high pH')
plt.plot(nm_em_rhoB_MECN_high, em_rhoB_MECN_high, label = 'MECN, high pH')
plt.ylabel('$L\ mol^{-1}cm^{-1}$')
plt.title('Emission Rhodamine B')
plt.legend()
plt.show()
# plot_spectra_nm(energRhB_wat, oscRhB_wat, legend='PCM-water')
# plot_spectra_nm(energRhB_eth, oscRhB_eth, legend='PCM-ethanol')
# plot_spectra_nm(energRhB_acet, oscRhB_acet, legend='PCM-acetonitrile')
# plot_spectra_nm(energRhB, oscRhB, legend='Gas-phase')

# %%
#Spectra Fluorescein
nm_abs_fluo_NAOH, abs_fluo_NAOH = np.loadtxt('experimental/200220_abs_0,1MNaOH_2,0uM_Flu.TXT', unpack=True)
nm_abs_fluo_ETOH, abs_fluo_ETOH = np.loadtxt('experimental/200220_abs_EtOH_2,0uM_Flu.TXT', unpack=True)
nm_abs_fluo_MECN, abs_fluo_MECN=np.loadtxt('experimental/200220_abs_MeCN_2,0uM_Flu.TXT', unpack=True)
nm_abs_fluo_ETOH_high, abs_fluo_ETOH_high = np.loadtxt('experimental/200220_abs_NaOH-EtOH_2,0uM_Flu.TXT', unpack=True)
nm_abs_fluo_MECN_high, abs_fluo_MECN_high = np.loadtxt('experimental/200220_abs_NaOH-MeCN_2,0uM_Flu.TXT', unpack=True)



energFluo, oscFluo = parse_Gaussian_file('theoretical/FluoES.log')
energFluo_wat, oscFluo_wat = parse_Gaussian_file('theoretical/Fluo_CPCM_waterES.log')
energFluo_eth, oscFluo_eth = parse_Gaussian_file('theoretical/Fluo_CPCM_ethanolES.log')
energFluo_acet, oscFluo_acet = parse_Gaussian_file('theoretical/Fluo_CPCM_acetoES.log')

plt.plot(nm_abs_fluo_NAOH, abs(abs_fluo_NAOH), label='NaOH')
plt.plot(nm_abs_fluo_ETOH, abs(abs_fluo_ETOH), label='EtOH')
plt.plot(nm_abs_fluo_MECN, abs(abs_fluo_MECN), label='MECN')
plt.plot(nm_abs_fluo_ETOH_high, abs(abs_fluo_ETOH_high), label='EtOH, high pH')
plt.plot(nm_abs_fluo_MECN_high, abs(abs_fluo_MECN_high), label='MECN, high pH')

plt.legend()
plt.ylabel('$L\ mol^{-1}cm^{-1}$')
plt.title('Absorption Fluorescein')
plt.xlim(300, 600)
plt.ylim(0,150000)
plt.show()
plt.plot(nm_em_fluo_NAOH, em_fluo_NAOH, label = 'NAOH')
plt.plot(nm_em_fluo_ETOH, em_fluo_ETOH, label = 'EtOH')
plt.plot(nm_em_fluo_MECN, em_fluo_MECN, label = 'MECN') 
plt.plot(nm_em_fluo_ETOH_high, em_fluo_ETOH_high, label = 'ETOH, high pH')
plt.plot(nm_em_fluo_MECN_high, em_fluo_MECN_high, label = 'MECN, high pH')
plt.title('Emission Nile Red')
plt.legend()
plt.show()
# plot_spectra_nm(energFluo_wat, oscFluo_wat, legend='PCM-water')
# plot_spectra_nm(energFluo_eth, oscFluo_eth, legend='PCM-ethanol')
# plot_spectra_nm(energFluo_acet, oscFluo_acet, legend='PCM-acetonitrile')
# plot_spectra_nm(energFluo, oscFluo, legend='Gas-phase')

# %%
#Spectra Nile Red
nm_abs_nr_NAOH, abs_nr_NAOH = np.loadtxt('experimental/200220_abs_0,1MNaOH_2,0uM_NR.TXT', unpack=True, skiprows=32)
nm_abs_nr_ETOH, abs_nr_ETOH=np.loadtxt('experimental/200220_abs_EtOH_2,0uM_NR.TXT', unpack=True, skiprows=32)
nm_abs_nr_MECN, abs_nr_MECN=np.loadtxt('experimental/200220_abs_MeCN_2,0uM_NR.TXT', unpack=True, skiprows=32)
nm_abs_nr_ETOH_high, abs_nr_ETOH_high = np.loadtxt('experimental/200220_abs_NaOH-EtOH_2,0uM_NR.TXT', unpack=True, skiprows=32)
nm_abs_nr_MECN_high, abs_nr_MECN_high = np.loadtxt('experimental/200220_abs_NaOH-MeCN_2,0uM_NR.TXT', unpack=True, skiprows=32)

nm_em_nr_NAOH, em_nr_NAOH = np.loadtxt('experimental/200220_em_0,1MNaOH_2,0uM_NR.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_nr_ETOH, em_nr_ETOH = np.loadtxt('experimental/200220_em_EtOH_2,0uM_NR.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_nr_MECN, em_nr_MECN = np.loadtxt('experimental/200220_em_MeCN_2,0uM_NR.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_nr_ETOH_high, em_nr_ETOH_high = np.loadtxt('experimental/200220_em_NaOH-EtOH_2,0uM_NR.ifx', usecols=(0,1), unpack=True, skiprows=28)
nm_em_nr_MECN_high, em_nr_MECN_high = np.loadtxt('experimental/200220_em_NaOH-MeCN_2,0uM_NR.ifx', usecols=(0,1), unpack=True, skiprows=28)

energNr, oscNr = parse_Gaussian_file('theoretical/NieredES.log')
energNr_wat, oscNr_wat = parse_Gaussian_file('theoretical/Niered_CPM_waterES.log')
energNr_eth, oscNr_eth = parse_Gaussian_file('theoretical/Niered_CPM_ethanolES.log')
energNr_acet, oscNr_acet = parse_Gaussian_file('theoretical/Niered_CPM_acetoES.log')

plt.plot(nm_abs_nr_NAOH, abs(abs_nr_NAOH), label='NaOH')
plt.plot(nm_abs_nr_ETOH, abs(abs_nr_ETOH), label='EtOH')
plt.plot(nm_abs_nr_MECN, abs(abs_nr_MECN), label='MECN')
plt.plot(nm_abs_nr_ETOH_high, abs(abs_nr_ETOH_high), label='EtOH, high pH')
plt.plot(nm_abs_nr_MECN_high, abs(abs_nr_MECN_high), label='MECN, high pH')
plt.legend()
plt.ylabel('$L\ mol^{-1}cm^{-1}$')
plt.title('Absorption Nilered')
plt.xlim(300, 600)
plt.ylim(0,200000)
plt.show()

plt.plot(nm_em_fluo_NAOH, em_fluo_NAOH, label = 'NAOH')
plt.plot(nm_em_fluo_ETOH, em_fluo_ETOH, label = 'EtOH')
plt.plot(nm_em_fluo_MECN, em_fluo_MECN, label = 'MECN') 
plt.plot(nm_em_fluo_ETOH_high, em_fluo_ETOH_high, label = 'ETOH, high pH')
plt.plot(nm_em_fluo_MECN_high, em_fluo_MECN_high, label = 'MECN, high pH')
plt.legend()
plt.ylabel('$L\ mol^{-1}cm^{-1}$')
plt.title('Emission Nilered')
# plt.xlim(300, 600)
# plt.ylim(0,200000)
# plot_spectra_nm(energNr_wat, oscNr_wat, legend='PCM-water')
# plot_spectra_nm(energNr_eth, oscNr_eth, legend='PCM-ethanol')
# plot_spectra_nm(energNr_acet, oscNr_acet, legend='PCM-acetonitrile')
# plot_spectra_nm(energNr, oscNr, legend='Gas-phase')
# Out:
# Text(0.5, 1.0, 'Emission Nilered')

# %%
#Spectra Nile Red 1
nm_nr1_NAOH, abs_nr1_NAOH = np.loadtxt('experimental/200220_abs_0,1MNaOH_2,0uM_NRA1.TXT', unpack=True, skiprows=32)
nm_nr1_ETOH, abs_nr1_ETOH=np.loadtxt('experimental/200220_abs_EtOH_2,0uM_NRA1.TXT', unpack=True, skiprows=32)
nm_nr1_MECN, abs_nr1_MECN=np.loadtxt('experimental/200220_abs_MeCN_2,0uM_NRA1.TXT', unpack=True, skiprows=32)
nm_nr1_EtOH, abs_nr1_EtOH = np.loadtxt('experimental/200220_abs_NaOH-EtOH_2,0uM_NRA1.TXT', unpack=True, skiprows=32)
nm_nr1_MECN, abs_nr1_MECN = np.loadtxt('experimental/200220_abs_NaOH-MeCN_2,0uM_NRA1.TXT', unpack=True, skiprows=32)
energNr1, oscNr1 = parse_Gaussian_file('theoretical/NieredES.log')
energNr1_wat, oscNr1_wat = parse_Gaussian_file('theoretical/Niered1_CPM_waterES.log')
energNr1_eth, oscNr1_eth = parse_Gaussian_file('theoretical/Niered1_CPM_ethanolES.log')
energNr1_acet, oscNr1_acet = parse_Gaussian_file('theoretical/Niered1_CPM_acetoES.log')
#Spectra DHE
energDHE, oscDHE = parse_Gaussian_file('theoretical/DHEES.log')
energDHE_wat, oscDHE_wat = parse_Gaussian_file('theoretical/DHE_CPCM_waterES.log')
energDHE_eth, oscDHE_eth = parse_Gaussian_file('theoretical/DHE_CPCM_ethanolES.log')
energDHE_acet, oscDHE_acet = parse_Gaussian_file('theoretical/DHE_CPCM_acetoES.log')
#Spectra ATTO488
nm_AT488_PBS, abs_AT488_PBS = np.loadtxt('experimental/181004_abs_PBS_1,786uM_AT488.TXT',unpack=True, skiprows=32)
nm_AT488_NAOH, abs_AT488_NAOH, = np.loadtxt('experimental/200311_abs_0,1MNaOH_2,0uM_AT488.TXT',unpack=True, skiprows=32)
nm_AT488_ETOH, abs_AT488_ETOH = np.loadtxt('experimental/200311_abs_EtOH_2,0uM_AT488.TXT',unpack=True, skiprows=34)
nm_AT488_MECN, abs_AT488_MECN = np.loadtxt('experimental/200311_abs_MeCN_2,0uM_AT488.TXT',unpack=True, skiprows=32)
nm_AT488_ETOH_high, abs_AT488_ETOH_high = np.loadtxt('experimental/200311_abs_NaOH-EtOH_2,0uM_AT488.TXT',unpack=True, skiprows=32)
nm_AT488_MECN_high, abs_AT488_MECN_high = np.loadtxt('experimental/200311_abs_NaOH-MeCN_2,0uM_AT488.TXT',unpack=True, skiprows=32)
#Spectra ATTO532
nm_AT532_PBS, abs_AT532_PBS = np.loadtxt('experimental/181004_abs_PBS_1,867uM_AT532.TXT', unpack=True, skiprows=34)
nm_AT532_NAOH, abs_AT532_NAOH = np.loadtxt('experimental/200311_abs_0,1MNaOH_2,0uM_AT532.TXT', unpack=True, skiprows=34)
nm_AT532_ETOH, abs_AT532_ETOH = np.loadtxt('experimental/200311_abs_EtOH_2,0uM_AT532.TXT', unpack=True, skiprows=34)
nm_AT532_MECN, abs_AT532_MECN = np.loadtxt('experimental/200311_abs_MeCN_2,0uM_AT532.TXT', unpack=True, skiprows=34)
nm_AT532_ETOH_high, abs_AT532_ETOH_high = np.loadtxt('experimental/200311_abs_NaOH-EtOH_2,0uM_AT532.TXT', unpack=True, skiprows=34)
nm_AT532_MECN_high, abs_AT532_MECN_high = np.loadtxt('experimental/200311_abs_NaOH-MeCN_2,0uM_AT532.TXT', unpack=True, skiprows=34)
#Spectra STAR488
nm_ST488_PBS, abs_ST488_PBS = np.loadtxt('experimental/181004_abs_PBS_2,294uM_ST488.TXT',unpack=True, skiprows=34)
nm_ST488_NAOH, abs_ST488_NAOH, = np.loadtxt('experimental/200311_abs_0,1MNaOH_2,0uM_ST488.TXT',unpack=True, skiprows=34)
nm_ST488_ETOH, abs_ST488_ETOH = np.loadtxt('experimental/200311_abs_EtOH_2,0uM_ST488.TXT',unpack=True, skiprows=34)
nm_ST488_MECN, abs_ST488_MECN = np.loadtxt('experimental/200311_abs_MeCN_2,0uM_ST488.TXT',unpack=True, skiprows=34)
nm_ST488_ETOH_high, abs_ST488_ETOH_high = np.loadtxt('experimental/200311_abs_NaOH-EtOH_2,0uM_ST488.TXT',unpack=True, skiprows=34)
nm_ST488_MECN_high, abs_ST488_MECN_high = np.loadtxt('experimental/200311_abs_NaOH-MeCN_2,0uM_ST488.TXT',unpack=True, skiprows=34)
#Spectra STAR512
nm_ST512_PBS, abs_ST512_PBS = np.loadtxt('experimental/181004_abs_PBS_2,398uM_ST512.TXT',unpack=True, skiprows=34)
nm_ST512_NAOH, abs_ST512_NAOH, = np.loadtxt('experimental/200220_abs_0,1MNaOH_2,0uM_ST512.TXT',unpack=True, skiprows=34)
nm_ST512_ETOH, abs_ST512_ETOH = np.loadtxt('experimental/200220_abs_EtOH_2,0uM_ST512.TXT',unpack=True, skiprows=34)
nm_ST512_MECN, abs_ST512_MECN = np.loadtxt('experimental/200220_abs_MeCN_2,0uM_ST512.TXT',unpack=True, skiprows=34)
nm_ST512_ETOH_high, abs_ST512_ETOH_high = np.loadtxt('experimental/200220_abs_NaOH-EtOH_2,0uM_ST512.TXT',unpack=True, skiprows=34)
nm_ST512_MECN_high, abs_ST512_MECN_high = np.loadtxt('experimental/200220_abs_NaOH-MeCN_2,0uM_ST512.TXT',unpack=True, skiprows=34)
#Spectra STAR520
nm_ST520_NAOH, abs_ST520_NAOH, = np.loadtxt('experimental/200311_abs_0,1MNaOH_2,0uM_ST520.TXT',unpack=True, skiprows=34)
nm_ST520_ETOH, abs_ST520_ETOH = np.loadtxt('experimental/200311_abs_EtOH_2,0uM_ST520.TXT',unpack=True, skiprows=34)
nm_ST520_MECN, abs_ST520_MECN = np.loadtxt('experimental/200311_abs_MeCN_2,0uM_ST520.TXT',unpack=True, skiprows=34)
nm_ST520_ETOH_high, abs_ST520_ETOH_high = np.loadtxt('experimental/200311_abs_NaOH-EtOH_2,0uM_ST520.TXT',unpack=True, skiprows=34)
nm_ST520_MECN_high, abs_ST520_MECN_high = np.loadtxt('experimental/200311_abs_NaOH-MeCN_2,0uM_ST520.TXT',unpack=True, skiprows=34)

# %%
plt.plot(nm_AT488_PBS, abs(abs_AT488_PBS), label='PBS')
plt.plot(nm_AT488_NAOH, abs(abs_AT488_NAOH), label='NAOH')
plt.plot(nm_AT488_ETOH, abs(abs_AT488_ETOH), label = 'ETOH') 
plt.plot(nm_AT488_MECN, abs(abs_AT488_MECN), label = 'MECN') 
plt.plot(nm_AT488_ETOH_high, abs(abs_AT488_ETOH_high), label = 'ETOH, high') 
plt.plot(nm_AT488_MECN_high, abs(abs_AT488_MECN_high), label = 'MECN, high') 
plt.legend()
plt.ylabel('$\\frac{L}{molcm}$')
plt.title('ATTO488')
plt.xlim(300, 650)
plt.ylim(0,200000)
# Out:
# (0, 200000)

# %%
plt.plot(nm_AT532_PBS, abs(abs_AT532_PBS), label='PBS')
plt.plot(nm_AT532_NAOH, abs(abs_AT532_NAOH), label='NAOH')
plt.plot(nm_AT532_ETOH, abs(abs_AT532_ETOH), label = 'ETOH') 
plt.plot(nm_AT532_MECN, abs(abs_AT532_MECN), label = 'MECN') 
plt.plot(nm_AT532_ETOH_high, abs(abs_AT532_ETOH_high), label = 'ETOH, high') 
plt.plot(nm_AT532_MECN_high, abs(abs_AT532_MECN_high), label = 'MECN, high') 
plt.legend()
plt.ylabel('$\\frac{L}{molcm}$')
plt.title('ATTO532')
plt.xlim(300, 650)
plt.ylim(0,200000)
# Out:
# (0, 200000)

# %%
plt.plot(nm_ST488_PBS, abs(abs_ST488_PBS), label='PBS')
plt.plot(nm_ST488_NAOH, abs(abs_ST488_NAOH), label='NAOH')
plt.plot(nm_ST488_ETOH, abs(abs_ST488_ETOH), label = 'ETOH') 
plt.plot(nm_ST488_MECN, abs(abs_ST488_MECN), label = 'MECN') 
plt.plot(nm_ST488_ETOH_high, abs(abs_ST488_ETOH_high), label = 'ETOH, high') 
plt.plot(nm_ST488_MECN_high, abs(abs_ST488_MECN_high), label = 'MECN, high') 
plt.legend()
plt.ylabel('$\\frac{L}{molcm}$')
plt.title('STAR488')
plt.xlim(300, 650)
plt.ylim(0,200000)
# Out:
# (0, 200000)

# %%
plt.plot(nm_nr1_NAOH, abs(abs_nr1_NAOH), label='NaOH')
plt.plot(nm_nr1_EtOH, abs(abs_nr1_EtOH), label='EtOH')
plt.plot(nm_nr1_MECN, abs(abs_nr1_MECN), label='MECN')
plot_spectra_nm(energNr1_wat, oscNr1_wat, legend='PCM-water')
plot_spectra_nm(energNr1_eth, oscNr1_eth, legend='PCM-ethanol')
plot_spectra_nm(energNr1_acet, oscNr1_acet, legend='PCM-acetonitrile')
plot_spectra_nm(energNr1, oscNr1, legend='Gas-phase')
plt.legend()
plt.ylabel('$\\frac{L}{molcm}$')
plt.title('Nilered in High pH (0.1 M NaOH)')
plt.xlim(300, 600)
plt.ylim(0,200000)
plt.show()

# %%
plot_spectra_nm(energDHE_wat, oscDHE_wat, legend='PCM-water')
plot_spectra_nm(energDHE_eth, oscDHE_eth, legend='PCM-ethanol')
plot_spectra_nm(energDHE_acet, oscDHE_acet, legend='PCM-acetonitrile')
plot_spectra_nm(energDHE, oscDHE, legend='Gas-phase')
plt.legend()
plt.ylabel('$\\frac{L}{molcm}$')
plt.title('DHE in High pH (0.1 M NaOH)')
plt.xlim(250, 600)
plt.ylim(0,150000)
plt.show()
